# %% [markdown]
#                                                 ESTIMATION AND CONFIDENCE INTERVALS

# %% [markdown]
# A total of 15 print-heads were randomly selected and tested until failure. The durability of each print-head (in millions of characters) was recorded as follows:
# 1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29

# %%
# a. Build 99% Confidence Interval Using Sample Standard Deviation

# %%
#GIVEN DATA : 
#1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29
#Sample size:
#n=15

# %% [markdown]
# Step 1: Compute Sample Mean and Sample Standard Deviation

# %%
#Sample Mean:
                   # X_bar = summation(xi) / n  = 18.59/15
                   # X_bar = 1.239

# %%
#Sample Standard Deviation

                   # s = 0.2

# %%
#(a) 99% Confidence Interval

#Using Sample Standard Deviation

#We use the t-distribution:

#Sample size is small  ( 𝑛 < 30 )

#Population standard deviation is unknown

#Data is assumed to be approximately normally distributed

# %%
# T-interval : 
#Degrees of freedom  (n-1) : 14
#alpha : 0.01
#level of significance : 0.05

# %%
#Standard Error = 0.209 / sqrt(15) = 0.054
# Margin Error =2.977×0.054≈0.161

# %%
#99% Confidence Interval
#1.239±0.161
# ans = (1.078,1.400)

# %%
#Result
#99% confident that the true mean durability of the print-heads lies between 1.078 and 1.400 million characters.

# %% [markdown]
# (b) 99% Confidence Interval

# %% [markdown]
# Population SD is Known

# %%
#sigma = 0.2
#population standard deviation is known, we use the Z-distribution

# %%
# Z-test calculation
#z = (sample_mean - mu) / (sigma / math.sqrt(n))

# %%
#Standard Error = 0.2 / root 15
#Margin Error = 2.576 * 0.052 = 0.134

# %%
99% Confidence Interval
 #1.239 ± 0.134
# Ans (1.105,1.373)

#Result:
#With 99% confidence, the true mean durability lies between 1.105 and 1.373 million characters when the population standard deviation is known.

# %% [markdown]
# PYTHON CODE :

# %%
import numpy as np
from scipy.stats import t, norm

data = np.array([1.13,1.55,1.43,0.92,1.25,1.36,1.32,0.85,
                 1.07,1.48,1.20,1.33,1.18,1.22,1.29])

n = len(data)
mean = np.mean(data)
s = np.std(data, ddof=1)

# (a) t-interval
t_critical = t.ppf(0.995, n-1)
t_result = (mean - t_critical*(s/np.sqrt(n)),
        mean + t_critical*(s/np.sqrt(n)))

# (b) z-interval
sigma = 0.2
z_critical = norm.ppf(0.995)
z_result = (mean - z_critical*(sigma/np.sqrt(n)),
        mean + z_critical*(sigma/np.sqrt(n)))

print("99% CI using sample SD (t):", t_result)
print("99% CI using known SD (z):", z_result)
# Out:
# 99% CI using sample SD (t): (np.float64(1.0901973384384906), np.float64(1.3871359948948425))
# 99% CI using known SD (z): (np.float64(1.1056514133957607), np.float64(1.3716819199375725))

# %% [markdown]
# CONCLUSION:

# %%
#Result
#99% confident that the true mean durability of the print-heads lies between 1.078 and 1.400 million characters.

# %%
#Result:
#With 99% confidence, the true mean durability lies between 1.105 and 1.373 million characters when the population standard deviation is known.
